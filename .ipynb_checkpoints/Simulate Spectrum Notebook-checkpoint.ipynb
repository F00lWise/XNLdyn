# %% [markdown]
# # About this notebook
#
# This notebook calculates a spectrum for a single photon energy

# %%
import numpy as np
import matplotlib.pyplot as plt

# Multiprocessing
import multiprocessing as mp
from multiprocessing import Pool

# For the progress bar
from ipywidgets import IntProgress
from IPython.display import display

# This package
import XNLdyn

# %matplotlib notebook

# %%
use_multiprocessing = True

## Set up the problem
PAR = XNLdyn.XNLpars()
PAR.tdur_sig = [10,]
PAR.E_j = [845,]
PAR.Nsteps_z = 50

pulse_energy_max = 10e-6  # Joule

N_local_fluences_to_calculate = 50
N_pulse_energies = 20

Nsteps_r = 100

pulse_profile_sigma= 1000 # nm rms

sim_options = dict(t_span=[-100, 100],method='RK45', rtol=1e-7, atol=1e-9, plot = False)

# %% [markdown]
# ## Run a simulation for a single Fluence

# %%
# %%time
fluences_joules_nm2, dA = XNLdyn.calculate_fluences(Nsteps_r, pulse_energy_max, pulse_profile_sigma) # These are just to get an idea where to calculate Fluences

fluences_simulated = np.logspace(np.log10(np.min(fluences_joules_nm2)),
                                 np.log10(np.max(fluences_joules_nm2)),
                                 N_local_fluences_to_calculate)

XNLdyn.run_modified_simulation(PAR, dict(t_span=[-100, 100],method='RK45', rtol=1e-7, atol=1e-9, plot = True),
                               ['I0',] , [np.max(fluences_joules_nm2)* XNLdyn.photons_per_J(PAR.E_j[0]),])
# Out:
# Initializing a simulation where ['I0'] are changed to [73854.9966627047]
# <img src="data:image/png;base64,..." width="871.7500000000001">
# Transmission:  [46.33716593]  %
# CPU times: user 33.1 s, sys: 196 ms, total: 33.3 s
# Wall time: 33.1 s
# (array([73855.07539698]), array([34222.34883102]))

# %% [markdown]
# # Load a spectrum to simulate

# %%
N_points_E = 30
E_fermi = 850.7#850.33
Erange = 3
E_min, E_max = E_fermi-Erange, E_fermi+Erange
enax_abs = np.linspace(E_min, E_max+2, N_points_E) # Absolute energy axis to sample
enax_rel = enax_abs-E_fermi # Rélative energy axis to Fermi Energy, i.e. detuning

ld = np.load('../../Penetration_depth_cold_spectrum.npz', allow_pickle=True)
pendepths = np.interp(enax_abs, ld['enax'],ld['spectrum'])

plt.figure()
plt.plot(enax_abs, pendepths,'.-')
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %% [markdown]
# ## Run it for all the fluences in the spot

# %%
# %%time

progressbar = IntProgress(min=0, max=N_points_E*N_local_fluences_to_calculate) # instantiate the bar
display(progressbar) # display the bar

try:
    mp.set_start_method('fork')  # 'spawn' on windows, "fork" or "forkserver" on unix machines
except RuntimeError:
    pass
with Pool(processes=50) as pool:
    tasklist = {}
    for photon_energy, pendepdth in zip(enax_abs, pendepths):
        for fluence in fluences_simulated:
            progressbar.value += 1
            fluence_photons = fluence* XNLdyn.photons_per_J(photon_energy)
            tasklist[(photon_energy,fluence)]=\
                pool.apply_async(XNLdyn.run_modified_simulation,(*(PAR, sim_options,
                                            ['I0','E_j', 'lambda_res_Ej'] ,
                                            [(fluence_photons,),(photon_energy,),(pendepdth,)]),)
                                             )


    #tasklist = [pool.apply_async(XNLdyn.run_modified_simulation,(*(PAR, sim_options,  ['I0',] , [fluence,]),)
    #                                     ) for fluence in fluences_simulated]
    resultdict = {key: tasklist[key].get(timeout=70) for key in tasklist}
# Out:
# IntProgress(value=0, max=1500)
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.39523870307129894,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.5063061933460016,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.6485851699960603,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.8308464882856781,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1.064325733967737,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1.3634158463175259,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1.746554377727828,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(2.2373600854055367,), (847.7,), (615.9438308554943,)]
#
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(2.866088920906142,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(3.6714991726743165,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(4.703240739190461,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(6.02491582060423,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(7.717999706648051,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(9.88686335966852,), (847.7,), (615.9438308554943,)]
#
#
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(12.66520741229847,), (847.7,), (615.9438308554943,)]
#
#
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(16.22430420661929,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(26.624019915427425,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(20.783555959242992,), (847.7,), (615.9438308554943,)]
#
#
#
#
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(34.1057342567905,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(43.68991282645451,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(55.967376876020204,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(71.69497652295242,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(91.8422471364574,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(117.65117680697948,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(247.31906651136524,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(150.71276929343063,), (847.7,), (615.9438308554943,)]
#
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(405.8496234049329,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(316.8191124356249,), (847.7,), (615.9438308554943,)]
#
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(193.0651222074921,), (847.7,), (615.9438308554943,)]
#
# Found value up to -19.349017706140117 under minimum of 0.
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(519.8989276614251,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(665.9976488725586,), (847.7,), (615.9438308554943,)]
# Found value up to -7.194160020692735 under minimum of 0.
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1092.899543881618,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(853.1521122748564,), (847.7,), (615.9438308554943,)]
#
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1400.0192882741694,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1793.44388833602,), (847.7,), (615.9438308554943,)]
#
#
# Found value up to -37.16475547372134 under minimum of 0.
# Found value up to -63.678033210829554 under minimum of 0.
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(3770.06741744265,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(2943.03442490796,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(2297.4261908739686,), (847.7,), (615.9438308554943,)]
#
#
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(6186.665925774851,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(4829.508011109044,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(7925.203807324058,), (847.7,), (615.9438308554943,)]
#
#
#
# Found value up to -103.71309062658183 under minimum of 0.
# Found value up to -13254128.794916673 under minimum of 0.
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(10152.294651300046,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(13005.228533247768,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(16659.875920794315,), (847.7,), (615.9438308554943,)]
#
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(21341.529292369145,), (847.7,), (615.9438308554943,)]
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(35021.366319912646,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(27338.791399313905,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(44862.8500433374,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(57469.925519913486,), (847.7,), (615.9438308554943,)]
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(73619.7619204735,), (847.7,), (615.9438308554943,)]
#
#
#
#
#
# Found value up to -164.99118723036642 under minimum of 0.
# Found value up to -7875507.474440107 under minimum of 0.
# Found value up to -185.357752428683 under minimum of 0.
# Found value up to -7395930.30325543 under minimum of 0.
# Found value up to -103.51014040766194 under minimum of 0.
# Found value up to -42.3464446191313 under minimum of 0.
# Found value up to -13737166.332480293 under minimum of 0.
# Found value up to -6.951577023839359 under minimum of 0.
# Transmission:  [96.07461794]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.39523870307129894,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.06632129]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.5063061933460016,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.03958367]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.6485851699960603,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.05729667]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.8308464882856781,), (847.9758620689655,), (616.9182113727219,)]
# Transmission:  [96.03195149]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1.064325733967737,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.04818]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1.3634158463175259,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.01618379]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1.746554377727828,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.02550593]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(2.2373600854055367,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.09950203]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(2.866088920906142,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.02027956]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(3.6714991726743165,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.0873464]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(4.703240739190461,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.01079556]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(6.02491582060423,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.00920592]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(7.717999706648051,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.09158073]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(9.88686335966852,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.10021021]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(12.66520741229847,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.0817016]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(16.22430420661929,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.00818678]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(20.783555959242992,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.01307422]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(26.624019915427425,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.09893574]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(34.1057342567905,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.00764492]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(43.68991282645451,), (847.9758620689655,), (616.9182113727219,)]
#
# Found value up to -5.189629721118898 under minimum of 0.
# Found value up to -33.84327983682462 under minimum of 0.
# Found value up to -16.770228439656325 under minimum of 0.
# Found value up to -59.39356113264361 under minimum of 0.
# Transmission:  [96.09804517]  %Transmission:
#  Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(55.967376876020204,), (847.9758620689655,), (616.9182113727219,)]
#
# [96.09460125]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(71.69497652295242,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.10036849]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(91.8422471364574,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.1003851]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(117.65117680697948,), (847.9758620689655,), (616.9182113727219,)]
#
# Found value up to -98.1758967241342 under minimum of 0.
# Found value up to -13342714.521973683 under minimum of 0.
# Found value up to -157.81773953907805 under minimum of 0.
# Found value up to -7887227.652020752 under minimum of 0.
# Found value up to -178.77386913449354 under minimum of 0.
# Found value up to -7391222.507512489 under minimum of 0.
# Found value up to -98.85843597959021 under minimum of 0.
# Found value up to -13573454.833981175 under minimum of 0.
# Transmission:  [96.09667092]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(150.71276929343063,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.10033987]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(193.0651222074921,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.09985671]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(247.31906651136524,), (847.9758620689655,), (616.9182113727219,)]
#
# Found value up to -39.37750921477268 under minimum of 0.
# Transmission:  [96.10007606]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(316.8191124356249,), (847.9758620689655,), (616.9182113727219,)]
#
# Found value up to -5.245690748722453 under minimum of 0.
# Transmission:  [96.10029135]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(405.8496234049329,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.00916159]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(519.8989276614251,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.00751084]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(665.9976488725586,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  [96.01378085]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(853.1521122748564,), (847.9758620689655,), (616.9182113727219,)]
#
# Transmission:  Transmission: [96.00773608]   %[96.01611184]
#   %Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1092.899543881618,),
  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(150.71276929343063,), (848.5275862068966,), (603.8806729289474,)]
#
# Found value up to -29.355626495805925 under minimum of 0.
# Transmission:  [95.99602754]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(193.0651222074921,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [95.99483234]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(247.31906651136524,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [95.9941194]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(316.8191124356249,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [95.99381492]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(405.8496234049329,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [95.9938648]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(519.8989276614251,), (848.5275862068966,), (603.8806729289474,)]
# Transmission:  [95.99423254]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(665.9976488725586,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [95.9948974]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(853.1521122748564,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [95.99710797]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1092.899543881618,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [95.99585321]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1400.0192882741694,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [95.99868428]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1793.44388833602,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.00062086]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(2297.4261908739686,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.00582654]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(2943.03442490796,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.00297501]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(3770.06741744265,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.00928318]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(4829.508011109044,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.01348784]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(6186.665925774851,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.0186282]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(7925.203807324058,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.02494895]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(10152.294651300046,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [95.99844684]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(13005.228533247768,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.02392571]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(16659.875920794315,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.02404681]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(21341.529292369145,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.03276707]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(27338.791399313905,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.04249089]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(35021.366319912646,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.00461065]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(44862.8500433374,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.02405948]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(57469.925519913486,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.0173544]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(73619.7619204735,), (848.5275862068966,), (603.8806729289474,)]
#
# Transmission:  [96.0212217]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.39523870307129894,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.02402494]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.5063061933460016,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.02398782]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.6485851699960603,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.02227]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.8308464882856781,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.00990792]  %Transmission:
# [96.02338357]Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1.064325733967737,), (848.8034482758621,), (600.0623895091292,)]
#
#  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1.3634158463175259,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.023823]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1.746554377727828,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.01964645]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(2.2373600854055367,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.01415382]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(2.866088920906142,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.02365505]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(3.6714991726743165,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.02295043]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(4.703240739190461,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.0546431]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(6.02491582060423,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.9917889]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(7.717999706648051,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.97885774]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(9.88686335966852,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.98511064]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(12.66520741229847,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.97334548]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(16.22430420661929,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.06988854]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(20.783555959242992,), (848.8034482758621,), (600.0623895091292,)]
#
# Found value up to -0.286462968402148 under minimum of 0.
# Transmission:  [95.96872607]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(26.624019915427425,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.96501567]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(34.1057342567905,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.08906702]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(43.68991282645451,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.11323115]  %
# Found value up to -10.68581204800756 under minimum of 0.
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(55.967376876020204,), (848.8034482758621,), (600.0623895091292,)]
#
# Found value up to -26.3722081712582 under minimum of 0.
# Transmission:  [95.96214577]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(71.69497652295242,), (848.8034482758621,), (600.0623895091292,)]
#
# Found value up to -50.35439210830643 under minimum of 0.
# Found value up to -87.47088152588391 under minimum of 0.
# Found value up to -12009898.404281221 under minimum of 0.
# Found value up to -145.5440155300487 under minimum of 0.
# Found value up to -7715339.844053173 under minimum of 0.
# Transmission:  [95.96001046]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(91.8422471364574,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.1436886]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(117.65117680697948,), (848.8034482758621,), (600.0623895091292,)]
# Found value up to -149.18060926216685 under minimum of 0.
# Found value up to -7509158.86104671 under minimum of 0.
# Found value up to -76.41457574696307 under minimum of 0.
# Found value up to -17619458.0623355 under minimum of 0.
# Transmission:  [95.95849809]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(150.71276929343063,), (848.8034482758621,), (600.0623895091292,)]
#
# Found value up to -25.264587448884626 under minimum of 0.
# Transmission:  [95.95750802]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(193.0651222074921,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.9569574]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(247.31906651136524,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [96.18204642]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(316.8191124356249,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.95678225]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(405.8496234049329,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.95738959]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(519.8989276614251,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.95693638]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(665.9976488725586,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.95812611]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(853.1521122748564,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.95914379]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1092.899543881618,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.96045385]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1400.0192882741694,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.96208164]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1793.44388833602,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.96406824]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(2297.4261908739686,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.97289422]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(2943.03442490796,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.96647321]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(3770.06741744265,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.99768833]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(4829.508011109044,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.96937853]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(6186.665925774851,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.99924431]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(7925.203807324058,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.99927472]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(10152.294651300046,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.99867597]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(13005.228533247768,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.99926359]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(16659.875920794315,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.99906558]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(21341.529292369145,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.99675888]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(27338.791399313905,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.99891671]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(35021.366319912646,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.9982918]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(44862.8500433374,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.99333369]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(57469.925519913486,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.9771658]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(73619.7619204735,), (848.8034482758621,), (600.0623895091292,)]
#
# Transmission:  [95.995363]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.39523870307129894,), (849.0793103448276,), (591.0041871248942,)]
#
# Transmission:  [95.99921152]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.5063061933460016,), (849.0793103448276,), (591.0041871248942,)]
# Transmission:
#  [95.99915656]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.6485851699960603,), (849.0793103448276,), (591.0041871248942,)]
#
# Transmission:  [95.98675445]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(0.8308464882856781,), (849.0793103448276,), (591.0041871248942,)]
#
# Transmission:  [95.97666561]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1.064325733967737,), (849.0793103448276,), (591.0041871248942,)]
#
# Transmission:  [95.98208601]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1.3634158463175259,), (849.0793103448276,), (591.0041871248942,)]
#
# Transmission:  [95.95472428]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1.746554377727828,), (849.0793103448276,), (591.0041871248942,)]
#
# Transmission:  [95.99050337]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(2.2373600854055367,), (849.0793103448276,), (591.0041871248942,)]
#
# Transmission:  [95.96498001]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(2.866088920906142,), (849.0793103448276,), (591.0041871248942,)]
#
# Transmission:  [95.95952203]  %
# ...
#  %
#
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(43.68991282645451,), (855.4241379310346,), (329.0863337191884,)]
#
# Found value up to -47673907.547391035 under minimum of 0.
# Found value up to -7476030.57513303 under minimum of 0.
# Found value up to -9662812.439737756 under minimum of 0.
# Transmission:  [93.07633936]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(55.967376876020204,), (855.4241379310346,), (329.0863337191884,)]
#
# Transmission:  [93.13502634]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(71.69497652295242,), (855.4241379310346,), (329.0863337191884,)]
#
# Found value up to -8442217.42079441 under minimum of 0.
# Transmission:  [93.29960359]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(91.8422471364574,), (855.4241379310346,), (329.0863337191884,)]
#
# Transmission:  [92.97299854]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(117.65117680697948,), (855.4241379310346,), (329.0863337191884,)]
#
# Transmission:  [93.41285449]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(150.71276929343063,), (855.4241379310346,), (329.0863337191884,)]
#
# Transmission:  [92.97745551]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(193.0651222074921,), (855.4241379310346,), (329.0863337191884,)]
#
# Transmission:  [92.98174855]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(247.31906651136524,), (855.4241379310346,), (329.0863337191884,)]
#
# Transmission:  [93.55250589]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(316.8191124356249,), (855.4241379310346,), (329.0863337191884,)]
#
# Transmission:  [93.72332203]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(405.8496234049329,), (855.4241379310346,), (329.0863337191884,)]
#
# Transmission:  [92.98606629]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(519.8989276614251,), (855.4241379310346,), (329.0863337191884,)]
#
# Transmission:  [92.99058893]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(665.9976488725586,), (855.4241379310346,), (329.0863337191884,)]
#
# Transmission:  [92.99549929]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(853.1521122748564,), (855.4241379310346,), (329.0863337191884,)]
#
# Transmission:  [93.00099385]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1092.899543881618,), (855.4241379310346,), (329.0863337191884,)]
#
# Transmission:  [92.82922503]  %
# Initializing a simulation where ['I0', 'E_j', 'lambda_res_Ej'] are changed to [(1400.0192882741694,), (855.4241379310346,), (329.0863337191884,)]
#
# Transmission:  [93
# Transmission:  [93.49958954]  %
# Transmission:  [93.23144362]  %
# Transmission:  [93.70650554]  %
# Transmission:  [93.25424585]  %
# Transmission:  [93.42527825]  %
# Transmission:  [93.26262829]  %
# Transmission:  [93.59203531]  %
# Transmission:  [93.26960194]  %
# Transmission:  [93.27554376]  %
# Transmission:  [93.28077081]  %
# Transmission:  [93.84731512]  %
# Transmission:  [94.01901352]  %
# Transmission:  [93.2855512]  %
# Transmission:  [93.29011734]  %
# Transmission:  [93.29943701]  %
# Transmission:  [93.29467922]  %
# Transmission:  [93.30459336]  %
# Transmission:  [93.31036557]  %
# Transmission:  [93.31699861]  %
# Transmission:  [93.32477972]  %
# Transmission:  [93.33405529]  %
# Transmission:  [93.34525124]  %
# Transmission:  [93.35889767]  %
# Transmission:  [93.37565897]  %
# Transmission:  [93.39637025]  %
# Transmission:  [93.45410349]  %
# Transmission:  [93.42208053]  %
# Transmission:  [93.49407339]  %
# Transmission:  [93.54400497]  %
# Transmission:  [93.60635069]  %
# Transmission:  [93.68404558]  %
# Transmission:  [93.78052564]  %
# Transmission:  [93.89969476]  %
# Transmission:  [94.04581126]  %
# Transmission:  [94.223257]  %
# CPU times: user 4.49 s, sys: 3.54 s, total: 8.04 s
# Wall time: 7min 44s

# %% [markdown]
# ## Assemble the results into a Matrix

# %%
fl_dep_spectrum_I = np.zeros((N_points_E,N_local_fluences_to_calculate))
fl_dep_spectrum_T = np.zeros((N_points_E,N_local_fluences_to_calculate))

for i_photen in range(N_points_E):
    for i_pulseen in range(N_local_fluences_to_calculate):
        fl_dep_spectrum_I[i_photen, i_pulseen], fl_dep_spectrum_T[i_photen, i_pulseen]  = \
            resultdict[(enax_abs[i_photen],fluences_simulated[i_pulseen])]

# %%
T = fl_dep_spectrum_T/fl_dep_spectrum_I

fig, (ax1, ax2) = plt.subplots(1,2, figsize = (10,4))
ax1.plot(enax_abs,1e3*np.log10(1/T))
ax1.set_ylabel('Optical Density (mOD)')
ax1.set_xlabel('Photon Energy / eV')

plt.sca(ax2)
plt.plot(fluences_simulated*XNLdyn.photons_per_J(850), T[:,:].T, '.-')#, label ='For one z-stack'
plt.xlabel('Fluence (photons/nm2)')
plt.ylabel('Transmission')
#plt.xscale('log')
#plt.legend(loc = 'lower right')

plt.tight_layout()

#local_fluences, dA = XNLdyn.calculate_fluences(Nsteps_r, pulse_energy_max, pulse_profile_sigma)
#for lf in local_fluences:
#    ax2.axvline(lf*XNLdyn.photons_per_J(850))
# Out:
# <img src="data:image/png;base64,..." width="1089.9166666666667">

# %%
fl_dep_spectrum_T[i_photen,:]
# Out:
# array([3.67507787e-01, 4.70783729e-01, 6.03082825e-01, 7.72562383e-01,
#        9.89672531e-01, 1.26780300e+00, 1.62411193e+00, 2.08058413e+00,
#        2.66540230e+00, 3.41468999e+00, 4.37476350e+00, 5.60499892e+00,
#        7.18150606e+00, 9.20183193e+00, 1.17909177e+01, 1.51087593e+01,
#        1.93601255e+01, 2.48072082e+01, 3.17858646e+01, 4.07262608e+01,
#        1.89131545e-12, 1.78974400e-12, 1.69210378e-12, 1.59835119e-12,
#        1.50843485e-12, 1.42229618e-12, 1.33987000e-12, 1.26108517e-12,
#        1.18586515e-12, 1.11412862e-12, 1.04579001e-12, 9.80760089e-13,
#        9.18946469e-13, 8.60254153e-13, 8.04586010e-13, 7.51843260e-13,
#        7.01925920e-13, 6.54733231e-13, 6.10164060e-13, 5.68117278e-13,
#        5.28492108e-13, 4.91188455e-13, 4.56107201e-13, 3.64604628e-13,
#        2.47037513e-13, 1.63799078e-13, 1.06283983e-13, 6.74888463e-14,
#        4.19376419e-14, 2.55025629e-14, 1.51764944e-14, 8.83826307e-15,
#        5.03697969e-15, 2.80919117e-15, 1.53320493e-15, 8.18892582e-16,
#        4.28017460e-16, 2.18929282e-16, 1.09585738e-16, 5.36799426e-17])

# %%
# These are the pulse energies for which we evaluate stuff
final_pulse_energies = np.linspace(1/N_pulse_energies, 1, N_pulse_energies)* pulse_energy_max

final_transmissions = np.zeros((N_points_E, N_pulse_energies))
final_incidence_check = np.zeros((N_points_E, N_pulse_energies))
for i_photen in range(N_points_E):

    for ipe, pulse_en in enumerate(final_pulse_energies*XNLdyn.photons_per_J(enax_abs[i_photen])):
        local_fluences, dA = XNLdyn.calculate_fluences(Nsteps_r, pulse_en, pulse_profile_sigma)
        
        
        local_transmitted = np.interp(local_fluences, fluences_simulated*XNLdyn.photons_per_J(enax_abs[i_photen]), fl_dep_spectrum_T[i_photen,:])# tr[:, 0]
        
        local_incidence_check = np.interp(local_fluences, fluences_simulated*XNLdyn.photons_per_J(enax_abs[i_photen]), fl_dep_spectrum_I[i_photen,:])

        final_transmissions[i_photen,ipe] = np.sum(local_transmitted*dA)
        final_incidence_check[i_photen,ipe] = np.sum(local_incidence_check*dA) # should result equal final_pulse_energies

        
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (10,4))
plt.sca(ax1)
plt.plot(enax_abs,(final_incidence_check/final_transmissions) )#, label ='For one z-stack'
plt.xlabel('Fluence (photons/nm2)')
plt.ylabel('Transmission')

plt.sca(ax2)
plt.plot(final_pulse_energies, (final_transmissions/final_pulse_energies).T, '.-')
#plt.plot(final_pulse_energies/XNLdyn.photons_per_J(850), final_consintency_check/XNLdyn.photons_per_J(850), 'C2x-', label = 'Incident reproduced')
#plt.plot(final_pulse_energies/XNLdyn.photons_per_J(850), final_incidence_check/XNLdyn.photons_per_J(850), 'C3.-', label = 'Incidences reproduced for reference')
plt.xlabel('Pulse Energy (J)')
plt.ylabel('Transmitted photons')
#plt.legend(loc = 'lower left')
# Out:
# <img src="data:image/png;base64,..." width="1089.9166666666667">
# Text(0, 0.5, 'Transmitted photons')

# %%
final_transmissions
# Out:
# array([[3.53501866e+09, 7.06927348e+09, 1.06040359e+10, 1.41392291e+10,
#         1.76747919e+10, 2.12107592e+10, 2.47470884e+10, 2.82837506e+10,
#         3.18207780e+10, 3.53581267e+10, 3.88958675e+10, 4.24339300e+10,
#         4.59723154e+10, 4.95110705e+10, 5.30501441e+10, 5.65895117e+10,
#         6.01292426e+10, 6.36693303e+10, 6.72097284e+10, 7.07504065e+10],
